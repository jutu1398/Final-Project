Shufflenet_mAP = 0.323

#MobileNetv2 with non-local block
Mobilenetv2_nonlocal_AP = {1: 0.5838508681996437, 2: 0.43202784153189977, 3: 0.35166413283704834, 4: 0.18536757914429913, 5: 0.22683870280843849, 6: 0.5484754902515235, 7: 0.43537522493733793, 8: 0.592115013088904, 9: 0.16199363367765324, 10: 0.24815856053229038, 11: 0.11799650658976632, 12: 0.44723047247228065, 13: 0.3545025448689313, 14: 0.5095623803144916, 15: 0.5281224841538459, 16: 0.14075321641425004, 17: 0.3211883589500475, 18: 0.19687147057305837, 19: 0.5409504247564018, 20: 0.38007658541660355} 
Mobilenetv2_nonlocal_mAP = 0.332

# MobileNetv2 removing last two blocks of heads
Mobilenetv2_lastlayers_AP = {1: 0.6365792334162899, 2: 0.5323795643816793, 3: 0.5065435990445475, 4: 0.23911772056705743, 5: 0.28024937431646435, 6: 0.5830343716130266, 7: 0.4651757577575271, 8: 0.6758187683901772, 9: 0.22960199203010292, 10: 0.35509573187987753, 11: 0.20757130736749765, 12: 0.6273928946981415, 13: 0.47465875531264723, 14: 0.5907852530628701, 15: 0.5871208654191711, 16: 0.17408520391585658, 17: 0.41870787147703625, 18: 0.301060149298368, 19: 0.5816125055144589, 20: 0.43791525514736324, 21: 0.0}
Mobilenetv2_lastlayers_mAP = 0.405 



CLASSES_NAME = [
    "aeroplane",
    "bicycle",
    "bird",
    "boat",
    "bottle",
    "bus",
    "car",
    "cat",
    "chair",
    "cow",
    "dining table",
    "dog",
    "horse",
    "motor bike",
    "person",
    "potted plant",
    "sheep",
    "sofa",
    "train",
    "tv monitor",
]

# %%
plotframe = pd.DataFrame()
plotframe[0] = list(Baseline_AP.values())
plotframe[1] = CLASSES_NAME
plotframe = plotframe.sort_values(by=0, ascending=False)

plt.figure(figsize=(15,10))
plt.title("Average Precision By Class: Baseline")
plt.xticks(rotation=90)
sns.barplot(x=0, y=1, data=plotframe)
plt.ylabel("VOC Class Number")
plt.xlabel("Average Precision")
# Out:
# Text(0.5, 0, 'Average Precision')

# %%
Baseline_nonlocal_mAP = 0.489

#Mobienetv2 20 epochs Without Centerness
Mobilenetv2_30epochs_mAP = 0.378

#Mobilenetv2 20 epochs With Centerness
Mobilenetv2_20epochs_mAP = 0.426 

##### SHufflenet
Shufflenet_mAP = 0.323

#MobileNetv2 with non-local block
Mobilenetv2_nonlocal_mAP = 0.332

# MobileNetv2 removing last two blocks of heads
Mobilenetv2_mAP = 0.405 





plt.figure(figsize=(1,10))
plt.title("Mean Average Precision by Model")

sns.barplot(x=['Baseline', 'Baseline+Nonlocal Block', 'ShuffleNetv2', 'MobileNetv2', 'MobileNetv2+Nonlocal Block', 'MobileNetv2-Altered Heads'], y=[Baseline_mAP, Baseline_nonlocal_mAP, Mobilenetv2_20epochs_mAP, Shufflenet_mAP, Mobilenetv2_nonlocal_mAP, Mobilenetv2_lastlayers_mAP])
# Out:
# <AxesSubplot:title={'center':'Mean Average Precision by Model'}>
